# %% [markdown]
# ### Showcase: reading .connlu and saving to .csv + utilizing NER
#
# ##### Data available: https://nl.ijs.si/et/tmp/ParlaMint/Repo/
#
# ##### NoSketch Crystal: https://www.clarin.si/ske-beta/ (ask teamleads for user/pass)
#
#
# ##### Notebook requirements:
#    - connlu
#    - pandas
#    - networkx (optional)
#    - rapidfuzz (optional)

# %%
import networkx as nx
import pandas as pd
import os
from io import open
from conllu import parse_incr
from rapidfuzz import fuzz

# %%
def metadata_to_csv(directory):
    
    df = pd.DataFrame()
    for subdir, dirs, files in os.walk(directory):
        for file in files:
            if 'meta.tsv' in file:
                file_path = os.path.join(subdir, file)
                df_meta = pd.read_csv(file_path, sep='\t')
                df = pd.concat([df, df_meta])
                
    return df

# %%
# conllu utilization of NERs
def speech_to_csv(directory, df):

    conllu_files_path = './data/ParlaMint-RS.conllu/'
    
    ID_to_text = {}

    for path, years, _ in os.walk(conllu_files_path):
        for year in years:
            conllu_files = path + year
            for file in os.listdir(conllu_files):
                if 'conllu' in file:
                    conllu_file = open(conllu_files + '/' + file, "r", encoding="utf-8")

                    speech = ""
                    speech_id = None
                    for sentence in parse_incr(conllu_file):
                        if 'newdoc id' in sentence.metadata:
                            if speech_id != None:
                                ID_to_text[speech_id] = speech.rstrip()
                            speech_id = sentence.metadata['newdoc id']
                            speech = ""

                        speech += sentence.metadata['text'] + ' '
                        
                    ID_to_text[speech_id] = speech.rstrip()  
                    print("Done with file: ", file)

    df['speech'] = df.ID.apply(lambda x: ID_to_text.get(x, None))
    
    return df

# %%
parliament = '../data/ParlaMint-RS.conllu'
df = metadata_to_csv(parliament)
df = speech_to_csv(parliament, df)
df.head() # save this .csv when done
# Out:
# Done with file:  ParlaMint-RS_1997-12-03-0.conllu
# Done with file:  ParlaMint-RS_1997-12-29-0.conllu
# Done with file:  ParlaMint-RS_1998-02-19-0.conllu
# Done with file:  ParlaMint-RS_1998-02-20-0.conllu
# Done with file:  ParlaMint-RS_1998-03-24-0.conllu
# Done with file:  ParlaMint-RS_1998-04-06-0.conllu
# Done with file:  ParlaMint-RS_1998-04-07-0.conllu
# Done with file:  ParlaMint-RS_1998-05-26-0.conllu
# Done with file:  ParlaMint-RS_1998-05-27-0.conllu
# Done with file:  ParlaMint-RS_1998-09-28-0.conllu
# Done with file:  ParlaMint-RS_1998-10-20-0.conllu
# Done with file:  ParlaMint-RS_1998-11-17-0.conllu
# Done with file:  ParlaMint-RS_1998-11-18-0.conllu
# Done with file:  ParlaMint-RS_1998-12-07-0.conllu
# Done with file:  ParlaMint-RS_1998-12-08-0.conllu
# Done with file:  ParlaMint-RS_1998-12-28-0.conllu
# Done with file:  ParlaMint-RS_1999-02-04-0.conllu
# Done with file:  ParlaMint-RS_1999-03-23-0.conllu
# Done with file:  ParlaMint-RS_1999-07-15-0.conllu
# Done with file:  ParlaMint-RS_1999-11-09-0.conllu
# Done with file:  ParlaMint-RS_1999-11-10-0.conllu
# Done with file:  ParlaMint-RS_1999-11-11-0.conllu
# Done with file:  ParlaMint-RS_1999-12-21-0.conllu
# Done with file:  ParlaMint-RS_2000-04-11-0.conllu
# Done with file:  ParlaMint-RS_2000-05-03-0.conllu
# Done with file:  ParlaMint-RS_2000-07-12-0.conllu
# Done with file:  ParlaMint-RS_2000-07-13-0.conllu
# Done with file:  ParlaMint-RS_2000-10-09-0.conllu
# Done with file:  ParlaMint-RS_2000-10-23-0.conllu
# Done with file:  ParlaMint-RS_2000-10-24-0.conllu
# Done with file:  ParlaMint-RS_2001-01-22-0.conllu
# Done with file:  ParlaMint-RS_2001-01-23-0.conllu
# Done with file:  ParlaMint-RS_2001-01-25-0.conllu
# Done with file:  ParlaMint-RS_2001-02-12-0.conllu
# Done with file:  ParlaMint-RS_2001-02-13-0.conllu
# Done with file:  ParlaMint-RS_2001-02-14-0.conllu
# Done with file:  ParlaMint-RS_2001-02-15-0.conllu
# Done with file:  ParlaMint-RS_2001-02-27-0.conllu
# Done with file:  ParlaMint-RS_2001-03-27-0.conllu
# Done with file:  ParlaMint-RS_2001-03-28-0.conllu
# Done with file:  ParlaMint-RS_2001-03-29-0.conllu
# Done with file:  ParlaMint-RS_2001-03-30-0.conllu
# Done with file:  ParlaMint-RS_2001-04-09-0.conllu
# Done with file:  ParlaMint-RS_2001-04-10-0.conllu
# Done with file:  ParlaMint-RS_2001-04-11-0.conllu
# Done with file:  ParlaMint-RS_2001-04-12-0.conllu
# Done with file:  ParlaMint-RS_2001-04-17-0.conllu
# Done with file:  ParlaMint-RS_2001-04-18-0.conllu
# Done with file:  ParlaMint-RS_2001-04-19-0.conllu
# Done with file:  ParlaMint-RS_2001-04-23-0.conllu
# Done with file:  ParlaMint-RS_2001-04-24-0.conllu
# Done with file:  ParlaMint-RS_2001-04-25-0.conllu
# Done with file:  ParlaMint-RS_2001-04-26-0.conllu
# Done with file:  ParlaMint-RS_2001-05-03-0.conllu
# Done with file:  ParlaMint-RS_2001-05-04-0.conllu
# Done with file:  ParlaMint-RS_2001-05-08-0.conllu
# Done with file:  ParlaMint-RS_2001-05-09-0.conllu
# Done with file:  ParlaMint-RS_2001-05-10-0.conllu
# Done with file:  ParlaMint-RS_2001-05-11-0.conllu
# Done with file:  ParlaMint-RS_2001-05-14-0.conllu
# Done with file:  ParlaMint-RS_2001-05-15-0.conllu
# Done with file:  ParlaMint-RS_2001-05-16-0.conllu
# Done with file:  ParlaMint-RS_2001-05-17-0.conllu
# Done with file:  ParlaMint-RS_2001-05-21-0.conllu
# Done with file:  ParlaMint-RS_2001-05-22-0.conllu
# Done with file:  ParlaMint-RS_2001-05-23-0.conllu
# Done with file:  ParlaMint-RS_2001-05-24-0.conllu
# Done with file:  ParlaMint-RS_2001-05-28-0.conllu
# Done with file:  ParlaMint-RS_2001-05-30-0.conllu
# Done with file:  ParlaMint-RS_2001-05-31-0.conllu
# Done with file:  ParlaMint-RS_2001-06-11-0.conllu
# Done with file:  ParlaMint-RS_2001-06-12-0.conllu
# Done with file:  ParlaMint-RS_2001-06-13-0.conllu
# Done with file:  ParlaMint-RS_2001-06-14-0.conllu
# Done with file:  ParlaMint-RS_2001-06-18-0.conllu
# Done with file:  ParlaMint-RS_2001-06-19-0.conllu
# Done with file:  ParlaMint-RS_2001-06-20-0.conllu
# Done with file:  ParlaMint-RS_2001-06-21-0.conllu
# Done with file:  ParlaMint-RS_2001-06-25-0.conllu
# Done with file:  ParlaMint-RS_2001-06-26-0.conllu
# Done with file:  ParlaMint-RS_2001-06-27-0.conllu
# Done with file:  ParlaMint-RS_2001-07-09-0.conllu
# Done with file:  ParlaMint-RS_2001-07-10-0.conllu
# Done with file:  ParlaMint-RS_2001-07-11-0.conllu
# Done with file:  ParlaMint-RS_2001-07-12-0.conllu
# Done with file:  ParlaMint-RS_2001-07-16-0.conllu
# Done with file:  ParlaMint-RS_2001-09-17-0.conllu
# Done with file:  ParlaMint-RS_2001-09-18-0.conllu
# Done with file:  ParlaMint-RS_2001-09-19-0.conllu
# Done with file:  ParlaMint-RS_2001-09-20-0.conllu
# Done with file:  ParlaMint-RS_2001-09-24-0.conllu
# Done with file:  ParlaMint-RS_2001-10-02-0.conllu
# Done with file:  ParlaMint-RS_2001-10-03-0.conllu
# Done with file:  ParlaMint-RS_2001-10-04-0.conllu
# Done with file:  ParlaMint-RS_2001-10-08-0.conllu
# Done with file:  ParlaMint-RS_2001-10-22-0.conllu
# Done with file:  ParlaMint-RS_2001-10-24-0.conllu
# Done with file:  ParlaMint-RS_2001-10-30-0.conllu
# Done with file:  ParlaMint-RS_2001-10-31-0.conllu
# Done with file:  ParlaMint-RS_2001-11-05-0.conllu
# Done with file:  ParlaMint-RS_2001-11-06-0.conllu
# Done with file:  ParlaMint-RS_2001-11-07-0.conllu
# Done with file:  ParlaMint-RS_2001-11-08-0.conllu
# Done with file:  ParlaMint-RS_2001-11-19-0.conllu
# Done with file:  ParlaMint-RS_2001-11-20-0.conllu
# Done with file:  ParlaMint-RS_2001-11-21-0.conllu
# Done with file:  ParlaMint-RS_2001-11-22-0.conllu
# Done with file:  ParlaMint-RS_2001-11-26-0.conllu
# Done with file:  ParlaMint-RS_2001-11-27-0.conllu
# Done with file:  ParlaMint-RS_2001-11-28-0.conllu
# Done with file:  ParlaMint-RS_2001-12-03-0.conllu
# Done with file:  ParlaMint-RS_2001-12-04-0.conllu
# Done with file:  ParlaMint-RS_2001-12-05-0.conllu
# Done with file:  ParlaMint-RS_2001-12-06-0.conllu
# Done with file:  ParlaMint-RS_2001-12-10-0.conllu
# Done with file:  ParlaMint-RS_2001-12-11-0.conllu
# Done with file:  ParlaMint-RS_2001-12-12-0.conllu
# Done with file:  ParlaMint-RS_2001-12-13-0.conllu
# Done with file:  ParlaMint-RS_2001-12-17-0.conllu
# Done with file:  ParlaMint-RS_2001-12-20-0.conllu
# Done with file:  ParlaMint-RS_2001-12-21-0.conllu
# Done with file:  ParlaMint-RS_2001-12-26-0.conllu
# Done with file:  ParlaMint-RS_2001-12-27-0.conllu
# Done with file:  ParlaMint-RS_2002-01-22-0.conllu
# Done with file:  ParlaMint-RS_2002-01-23-0.conllu
# Done with file:  ParlaMint-RS_2002-01-24-0.conllu
# Done with file:  ParlaMint-RS_2002-01-28-0.conllu
# Done with file:  ParlaMint-RS_2002-01-29-0.conllu
# Done with file:  ParlaMint-RS_2002-01-30-0.conllu
# Done with file:  ParlaMint-RS_2002-01-31-0.conllu
# Done with file:  ParlaMint-RS_2002-02-04-0.conllu
# Done with file:  ParlaMint-RS_2002-02-05-0.conllu
# Done with file:  ParlaMint-RS_2002-02-06-0.conllu
# Done with file:  ParlaMint-RS_2002-02-07-0.conllu
# Done with file:  ParlaMint-RS_2002-02-11-0.conllu
# Done with file:  ParlaMint-RS_2002-02-12-0.conllu
# Done with file:  ParlaMint-RS_2002-02-13-0.conllu
# Done with file:  ParlaMint-RS_2002-02-14-0.conllu
# Done with file:  ParlaMint-RS_2002-02-18-0.conllu
# Done with file:  ParlaMint-RS_2002-02-19-0.conllu
# Done with file:  ParlaMint-RS_2002-02-20-0.conllu
# Done with file:  ParlaMint-RS_2002-02-21-0.conllu
# Done with file:  ParlaMint-RS_2002-02-25-0.conllu
# Done with file:  ParlaMint-RS_2002-02-26-0.conllu
# Done with file:  ParlaMint-RS_2002-02-27-0.conllu
# Done with file:  ParlaMint-RS_2002-03-27-0.conllu
# Done with file:  ParlaMint-RS_2002-03-28-0.conllu
# Done with file:  ParlaMint-RS_2002-04-02-0.conllu
# Done with file:  ParlaMint-RS_2002-04-03-0.conllu
# Done with file:  ParlaMint-RS_2002-04-04-0.conllu
# Done with file:  ParlaMint-RS_2002-04-09-0.conllu
# Done with file:  ParlaMint-RS_2002-04-10-0.conllu
# Done with file:  ParlaMint-RS_2002-04-11-0.conllu
# Done with file:  ParlaMint-RS_2002-04-15-0.conllu
# Done with file:  ParlaMint-RS_2002-04-16-0.conllu
# Done with file:  ParlaMint-RS_2002-04-17-0.conllu
# Done with file:  ParlaMint-RS_2002-04-18-0.conllu
# Done with file:  ParlaMint-RS_2002-04-22-0.conllu
# Done with file:  ParlaMint-RS_2002-04-23-0.conllu
# Done with file:  ParlaMint-RS_2002-04-24-0.conllu
# Done with file:  ParlaMint-RS_2002-04-25-0.conllu
# Done with file:  ParlaMint-RS_2002-05-08-0.conllu
# Done with file:  ParlaMint-RS_2002-05-09-0.conllu
# Done with file:  ParlaMint-RS_2002-05-13-0.conllu
# Done with file:  ParlaMint-RS_2002-05-14-0.conllu
# Done with file:  ParlaMint-RS_2002-05-15-0.conllu
# Done with file:  ParlaMint-RS_2002-05-21-0.conllu
# Done with file:  ParlaMint-RS_2002-05-22-0.conllu
# Done with file:  ParlaMint-RS_2002-06-04-0.conllu
# Done with file:  ParlaMint-RS_2002-06-05-0.conllu
# Done with file:  ParlaMint-RS_2002-06-06-0.conllu
# Done with file:  ParlaMint-RS_2002-06-11-0.conllu
# Done with file:  ParlaMint-RS_2002-06-12-0.conllu
# Done with file:  ParlaMint-RS_2002-06-18-0.conllu
# Done with file:  ParlaMint-RS_2002-06-19-0.conllu
# Done with file:  ParlaMint-RS_2002-07-02-0.conllu
# Done with file:  ParlaMint-RS_2002-07-03-0.conllu
# Done with file:  ParlaMint-RS_2002-07-09-0.conllu
# Done with file:  ParlaMint-RS_2002-07-10-0.conllu
# Done with file:  ParlaMint-RS_2002-07-11-0.conllu
# Done with file:  ParlaMint-RS_2002-07-15-0.conllu
# Done with file:  ParlaMint-RS_2002-07-16-0.conllu
# Done with file:  ParlaMint-RS_2002-07-17-0.conllu
# Done with file:  ParlaMint-RS_2002-11-05-0.conllu
# Done with file:  ParlaMint-RS_2002-11-12-0.conllu
# Done with file:  ParlaMint-RS_2002-11-19-0.conllu
# Done with file:  ParlaMint-RS_2002-11-20-0.conllu
# Done with file:  ParlaMint-RS_2002-11-21-0.conllu
# Done with file:  ParlaMint-RS_2002-12-03-0.conllu
# Done with file:  ParlaMint-RS_2002-12-10-0.conllu
# Done with file:  ParlaMint-RS_2002-12-11-0.conllu
# Done with file:  ParlaMint-RS_2002-12-12-0.conllu
# Done with file:  ParlaMint-RS_2002-12-13-0.conllu
# Done with file:  ParlaMint-RS_2002-12-17-0.conllu
# Done with file:  ParlaMint-RS_2002-12-18-0.conllu
# Done with file:  ParlaMint-RS_2003-01-27-0.conllu
# Done with file:  ParlaMint-RS_2003-02-05-0.conllu
# Done with file:  ParlaMint-RS_2003-02-06-0.conllu
# Done with file:  ParlaMint-RS_2003-02-11-0.conllu
# Done with file:  ParlaMint-RS_2003-02-12-0.conllu
# Done with file:  ParlaMint-RS_2003-02-13-0.conllu
# Done with file:  ParlaMint-RS_2003-02-19-0.conllu
# Done with file:  ParlaMint-RS_2003-02-20-0.conllu
# Done with file:  ParlaMint-RS_2003-02-25-0.conllu
# Done with file:  ParlaMint-RS_2003-02-26-0.conllu
# Done with file:  ParlaMint-RS_2003-02-27-0.conllu
# Done with file:  ParlaMint-RS_2003-02-28-0.conllu
# Done with file:  ParlaMint-RS_2003-03-13-0.conllu
# Done with file:  ParlaMint-RS_2003-03-18-0.conllu
# Done with file:  ParlaMint-RS_2003-03-19-0.conllu
# Done with file:  ParlaMint-RS_2003-03-25-0.conllu
# Done with file:  ParlaMint-RS_2003-03-26-0.conllu
# Done with file:  ParlaMint-RS_2003-04-01-0.conllu
# Done with file:  ParlaMint-RS_2003-04-02-0.conllu
# Done with file:  ParlaMint-RS_2003-04-08-0.conllu
# Done with file:  ParlaMint-RS_2003-04-09-0.conllu
# Done with file:  ParlaMint-RS_2003-04-10-0.conllu
# Done with file:  ParlaMint-RS_2003-04-11-0.conllu
# Done with file:  ParlaMint-RS_2003-04-15-0.conllu
# Done with file:  ParlaMint-RS_2003-04-16-0.conllu
# Done with file:  ParlaMint-RS_2003-04-17-0.conllu
# Done with file:  ParlaMint-RS_2003-04-18-0.conllu
# Done with file:  ParlaMint-RS_2003-04-22-0.conllu
# Done with file:  ParlaMint-RS_2003-04-23-0.conllu
# Done with file:  ParlaMint-RS_2003-04-24-0.conllu
# Done with file:  ParlaMint-RS_2003-05-13-0.conllu
# Done with file:  ParlaMint-RS_2003-05-14-0.conllu
# Done with file:  ParlaMint-RS_2003-05-15-0.conllu
# Done with file:  ParlaMint-RS_2003-05-20-0.conllu
# Done with file:  ParlaMint-RS_2003-05-21-0.conllu
# Done with file:  ParlaMint-RS_2003-05-27-0.conllu
# Done with file:  ParlaMint-RS_2003-05-28-0.conllu
# Done with file:  ParlaMint-RS_2003-05-29-0.conllu
# Done with file:  ParlaMint-RS_2003-05-30-0.conllu
# Done with file:  ParlaMint-RS_2003-06-04-0.conllu
# Done with file:  ParlaMint-RS_2003-06-05-0.conllu
# Done with file:  ParlaMint-RS_2003-06-10-0.conllu
# Done with file:  ParlaMint-RS_2003-06-11-0.conllu
# Done with file:  ParlaMint-RS_2003-06-17-0.conllu
# Done with file:  ParlaMint-RS_2003-06-18-0.conllu
# Done with file:  ParlaMint-RS_2003-06-19-0.conllu
# Done with file:  ParlaMint-RS_2003-06-24-0.conllu
# Done with file:  ParlaMint-RS_2003-06-25-0.conllu
# Done with file:  ParlaMint-RS_2003-07-01-0.conllu
# Done with file:  ParlaMint-RS_2003-07-02-0.conllu
# Done with file:  ParlaMint-RS_2003-07-03-0.conllu
# Done with file:  ParlaMint-RS_2003-07-08-0.conllu
# Done with file:  ParlaMint-RS_2003-07-09-0.conllu
# Done with file:  ParlaMint-RS_2003-07-10-0.conllu
# Done with file:  ParlaMint-RS_2003-07-14-0.conllu
# Done with file:  ParlaMint-RS_2003-07-15-0.conllu
# Done with file:  ParlaMint-RS_2003-07-16-0.conllu
# Done with file:  ParlaMint-RS_2003-07-17-0.conllu
# Done with file:  ParlaMint-RS_2003-07-18-0.conllu
# Done with file:  ParlaMint-RS_2003-07-22-0.conllu
# Done with file:  ParlaMint-RS_2003-08-27-0.conllu
# Done with file:  ParlaMint-RS_2003-10-14-0.conllu
# Done with file:  ParlaMint-RS_2003-10-16-0.conllu
# Done with file:  ParlaMint-RS_2003-10-22-0.conllu
# Done with file:  ParlaMint-RS_2003-10-23-0.conllu
# Done with file:  ParlaMint-RS_2003-10-28-0.conllu
# Done with file:  ParlaMint-RS_2003-10-29-0.conllu
# Done with file:  ParlaMint-RS_2003-10-30-0.conllu
# Done with file:  ParlaMint-RS_2003-10-31-0.conllu
# Done with file:  ParlaMint-RS_2003-11-03-0.conllu
# Done with file:  ParlaMint-RS_2003-11-04-0.conllu
# Done with file:  ParlaMint-RS_2003-11-05-0.conllu
# Done with file:  ParlaMint-RS_2003-11-06-0.conllu
# Done with file:  ParlaMint-RS_2004-01-27-0.conllu
# Done with file:  ParlaMint-RS_2004-01-27-1.conllu
# Done with file:  ParlaMint-RS_2004-02-04-0.conllu
# Done with file:  ParlaMint-RS_2004-02-09-0.conllu
# Done with file:  ParlaMint-RS_2004-02-12-0.conllu
# Done with file:  ParlaMint-RS_2004-02-17-0.conllu
# Done with file:  ParlaMint-RS_2004-02-18-0.conllu
# Done with file:  ParlaMint-RS_2004-02-19-0.conllu
# Done with file:  ParlaMint-RS_2004-02-20-0.conllu
# Done with file:  ParlaMint-RS_2004-02-23-0.conllu
# Done with file:  ParlaMint-RS_2004-02-24-0.conllu
# Done with file:  ParlaMint-RS_2004-02-26-0.conllu
# Done with file:  ParlaMint-RS_2004-03-02-0.conllu
# Done with file:  ParlaMint-RS_2004-03-03-0.conllu
# Done with file:  ParlaMint-RS_2004-03-04-0.conllu
# Done with file:  ParlaMint-RS_2004-03-16-0.conllu
# Done with file:  ParlaMint-RS_2004-03-17-0.conllu
# Done with file:  ParlaMint-RS_2004-03-23-0.conllu
# Done with file:  ParlaMint-RS_2004-03-26-0.conllu
# Done with file:  ParlaMint-RS_2004-03-30-0.conllu
# Done with file:  ParlaMint-RS_2004-04-07-0.conllu
# Done with file:  ParlaMint-RS_2004-04-08-0.conllu
# Done with file:  ParlaMint-RS_2004-04-13-0.conllu
# Done with file:  ParlaMint-RS_2004-04-14-0.conllu
# Done with file:  ParlaMint-RS_2004-04-15-0.conllu
# Done with file:  ParlaMint-RS_2004-04-19-0.conllu
# Done with file:  ParlaMint-RS_2004-04-20-0.conllu
# Done with file:  ParlaMint-RS_2004-04-21-0.conllu
# Done with file:  ParlaMint-RS_2004-04-29-0.conllu
# Done with file:  ParlaMint-RS_2004-05-05-0.conllu
# Done with file:  ParlaMint-RS_2004-05-07-0.conllu
# Done with file:  ParlaMint-RS_2004-05-10-0.conllu
# Done with file:  ParlaMint-RS_2004-05-11-0.conllu
# Done with file:  ParlaMint-RS_2004-05-12-0.conllu
# Done with file:  ParlaMint-RS_2004-05-13-0.conllu
# Done with file:  ParlaMint-RS_2004-05-17-0.conllu
# Done with file:  ParlaMint-RS_2004-05-18-0.conllu
# Done with file:  ParlaMint-RS_2004-05-21-0.conllu
# Done with file:  ParlaMint-RS_2004-05-24-0.conllu
# Done with file:  ParlaMint-RS_2004-05-25-0.conllu
# Done with file:  ParlaMint-RS_2004-05-26-0.conllu
# Done with file:  ParlaMint-RS_2004-05-27-0.conllu
# Done with file:  ParlaMint-RS_2004-05-28-0.conllu
# Done with file:  ParlaMint-RS_2004-06-29-0.conllu
# Done with file:  ParlaMint-RS_2004-06-30-0.conllu
# Done with file:  ParlaMint-RS_2004-07-01-0.conllu
# Done with file:  ParlaMint-RS_2004-07-05-0.conllu
# Done with file:  ParlaMint-RS_2004-07-06-0.conllu
# Done with file:  ParlaMint-RS_2004-07-07-0.conllu
# Done with file:  ParlaMint-RS_2004-07-08-0.conllu
# Done with file:  ParlaMint-RS_2004-07-11-0.conllu
# Done with file:  ParlaMint-RS_2004-07-12-0.conllu
# Done with file:  ParlaMint-RS_2004-07-13-0.conllu
# Done with file:  ParlaMint-RS_2004-07-14-0.conllu
# Done with file:  ParlaMint-RS_2004-07-15-0.conllu
# Done with file:  ParlaMint-RS_2004-07-19-0.conllu
# Done with file:  ParlaMint-RS_2004-07-20-0.conllu
# Done with file:  ParlaMint-RS_2004-07-21-0.conllu
# Done with file:  ParlaMint-RS_2004-07-22-0.conllu
# Done with file:  ParlaMint-RS_2004-07-23-0.conllu
# Done with file:  ParlaMint-RS_2004-08-17-0.conllu
# Done with file:  ParlaMint-RS_2004-08-18-0.conllu
# Done with file:  ParlaMint-RS_2004-08-19-0.conllu
# Done with file:  ParlaMint-RS_2004-08-24-0.conllu
# Done with file:  ParlaMint-RS_2004-08-25-0.conllu
# Done with file:  ParlaMint-RS_2004-08-26-0.conllu
# Done with file:  ParlaMint-RS_2004-10-06-0.conllu
# Done with file:  ParlaMint-RS_2004-10-07-0.conllu
# Done with file:  ParlaMint-RS_2004-10-13-0.conllu
# Done with file:  ParlaMint-RS_2004-10-14-0.conllu
# Done with file:  ParlaMint-RS_2004-10-18-0.conllu
# Done with file:  ParlaMint-RS_2004-10-19-0.conllu
# Done with file:  ParlaMint-RS_2004-10-21-0.conllu
# Done with file:  ParlaMint-RS_2004-10-26-0.conllu
# Done with file:  ParlaMint-RS_2004-10-27-0.conllu
# Done with file:  ParlaMint-RS_2004-11-02-0.conllu
# Done with file:  ParlaMint-RS_2004-11-03-0.conllu
# Done with file:  ParlaMint-RS_2004-11-04-0.conllu
# Done with file:  ParlaMint-RS_2004-11-05-0.conllu
# Done with file:  ParlaMint-RS_2004-11-08-0.conllu
# Done with file:  ParlaMint-RS_2004-11-09-0.conllu
# Done with file:  ParlaMint-RS_2004-11-10-0.conllu
# Done with file:  ParlaMint-RS_2004-11-11-0.conllu
# Done with file:  ParlaMint-RS_2004-11-12-0.conllu
# Done with file:  ParlaMint-RS_2004-11-13-0.conllu
# Done with file:  ParlaMint-RS_2004-11-18-0.conllu
# Done with file:  ParlaMint-RS_2004-11-19-0.conllu
# Done with file:  ParlaMint-RS_2004-12-01-0.conllu
# Done with file:  ParlaMint-RS_2004-12-02-0.conllu
# Done with file:  ParlaMint-RS_2004-12-03-0.conllu
# Done with file:  ParlaMint-RS_2004-12-06-0.conllu
# Done with file:  ParlaMint-RS_2004-12-07-0.conllu
# Done with file:  ParlaMint-RS_2004-12-08-0.conllu
# Done with file:  ParlaMint-RS_2004-12-09-0.conllu
# Done with file:  ParlaMint-RS_2004-12-10-0.conllu
# Done with file:  ParlaMint-RS_2004-12-11-0.conllu
# Done with file:  ParlaMint-RS_2004-12-13-0.conllu
# Done with file:  ParlaMint-RS_2004-12-14-0.conllu
# Done with file:  ParlaMint-RS_2004-12-15-0.conllu
# Done with file:  ParlaMint-RS_2004-12-16-0.conllu
# Done with file:  ParlaMint-RS_2004-12-17-0.conllu
# Done with file:  ParlaMint-RS_2004-12-21-0.conllu
# Done with file:  ParlaMint-RS_2004-12-22-0.conllu
# Done with file:  ParlaMint-RS_2005-01-18-0.conllu
# Done with file:  ParlaMint-RS_2005-01-19-0.conllu
# Done with file:  ParlaMint-RS_2005-01-20-0.conllu
# Done with file:  ParlaMint-RS_2005-01-24-0.conllu
# Done with file:  ParlaMint-RS_2005-01-25-0.conllu
# Done with file:  ParlaMint-RS_2005-01-26-0.conllu
# Done with file:  ParlaMint-RS_2005-01-31-0.conllu
# Done with file:  ParlaMint-RS_2005-02-01-0.conllu
# Done with file:  ParlaMint-RS_2005-02-02-0.conllu
# Done with file:  ParlaMint-RS_2005-02-03-0.conllu
# Done with file:  ParlaMint-RS_2005-02-07-0.conllu
# Done with file:  ParlaMint-RS_2005-02-08-0.conllu
# Done with file:  ParlaMint-RS_2005-02-09-0.conllu
# Done with file:  ParlaMint-RS_2005-02-10-0.conllu
# Done with file:  ParlaMint-RS_2005-02-11-0.conllu
# Done with file:  ParlaMint-RS_2005-02-16-0.conllu
# Done with file:  ParlaMint-RS_2005-02-17-0.conllu
# Done with file:  ParlaMint-RS_2005-02-18-0.conllu
# Done with file:  ParlaMint-RS_2005-02-28-0.conllu
# Done with file:  ParlaMint-RS_2005-03-08-0.conllu
# Done with file:  ParlaMint-RS_2005-03-09-0.conllu
# Done with file:  ParlaMint-RS_2005-03-17-0.conllu
# Done with file:  ParlaMint-RS_2005-03-21-0.conllu
# Done with file:  ParlaMint-RS_2005-03-22-0.conllu
# Done with file:  ParlaMint-RS_2005-03-23-0.conllu
# Done with file:  ParlaMint-RS_2005-03-24-0.conllu
# Done with file:  ParlaMint-RS_2005-03-29-0.conllu
# Done with file:  ParlaMint-RS_2005-03-30-0.conllu
# Done with file:  ParlaMint-RS_2005-03-31-0.conllu
# Done with file:  ParlaMint-RS_2005-04-05-0.conllu
# Done with file:  ParlaMint-RS_2005-04-06-0.conllu
# Done with file:  ParlaMint-RS_2005-04-12-0.conllu
# Done with file:  ParlaMint-RS_2005-04-13-0.conllu
# Done with file:  ParlaMint-RS_2005-04-14-0.conllu
# Done with file:  ParlaMint-RS_2005-04-19-0.conllu
# Done with file:  ParlaMint-RS_2005-04-20-0.conllu
# Done with file:  ParlaMint-RS_2005-04-21-0.conllu
# Done with file:  ParlaMint-RS_2005-04-25-0.conllu
# Done with file:  ParlaMint-RS_2005-04-26-0.conllu
# Done with file:  ParlaMint-RS_2005-05-10-0.conllu
# Done with file:  ParlaMint-RS_2005-05-11-0.conllu
# Done with file:  ParlaMint-RS_2005-05-12-0.conllu
# Done with file:  ParlaMint-RS_2005-05-16-0.conllu
# Done with file:  ParlaMint-RS_2005-05-17-0.conllu
# Done with file:  ParlaMint-RS_2005-05-18-0.conllu
# Done with file:  ParlaMint-RS_2005-05-19-0.conllu
# Done with file:  ParlaMint-RS_2005-05-20-0.conllu
# Done with file:  ParlaMint-RS_2005-05-23-0.conllu
# Done with file:  ParlaMint-RS_2005-05-24-0.conllu
# Done with file:  ParlaMint-RS_2005-05-30-0.conllu
# Done with file:  ParlaMint-RS_2005-05-31-0.conllu
# Done with file:  ParlaMint-RS_2005-06-01-0.conllu
# Done with file:  ParlaMint-RS_2005-06-02-0.conllu
# Done with file:  ParlaMint-RS_2005-06-21-0.conllu
# Done with file:  ParlaMint-RS_2005-06-22-0.conllu
# Done with file:  ParlaMint-RS_2005-06-24-0.conllu
# Done with file:  ParlaMint-RS_2005-06-27-0.conllu
# Done with file:  ParlaMint-RS_2005-06-28-0.conllu
# Done with file:  ParlaMint-RS_2005-06-29-0.conllu
# Done with file:  ParlaMint-RS_2005-06-30-0.conllu
# Done with file:  ParlaMint-RS_2005-07-04-0.conllu
# Done with file:  ParlaMint-RS_2005-07-05-0.conllu
# Done with file:  ParlaMint-RS_2005-07-06-0.conllu
# Done with file:  ParlaMint-RS_2005-07-07-0.conllu
# Done with file:  ParlaMint-RS_2005-07-11-0.conllu
# Done with file:  ParlaMint-RS_2005-07-12-0.conllu
# Done with file:  ParlaMint-RS_2005-07-13-0.conllu
# Done with file:  ParlaMint-RS_2005-07-18-0.conllu
# Done with file:  ParlaMint-RS_2005-07-19-0.conllu
# Done with file:  ParlaMint-RS_2005-07-20-0.conllu
# Done with file:  ParlaMint-RS_2005-07-21-0.conllu
# Done with file:  ParlaMint-RS_2005-07-22-0.conllu
# Done with file:  ParlaMint-RS_2005-07-23-0.conllu
# Done with file:  ParlaMint-RS_2005-08-22-0.conllu
# Done with file:  ParlaMint-RS_2005-08-23-0.conllu
# Done with file:  ParlaMint-RS_2005-08-24-0.conllu
# Done with file:  ParlaMint-RS_2005-08-25-0.conllu
# Done with file:  ParlaMint-RS_2005-08-29-0.conllu
# Done with file:  ParlaMint-RS_2005-08-30-0.conllu
# Done with file:  ParlaMint-RS_2005-08-31-0.conllu
# Done with file:  ParlaMint-RS_2005-09-01-0.conllu
# Done with file:  ParlaMint-RS_2005-09-05-0.conllu
# Done with file:  ParlaMint-RS_2005-09-06-0.conllu
# Done with file:  ParlaMint-RS_2005-09-07-0.conllu
# Done with file:  ParlaMint-RS_2005-09-08-0.conllu
# Done with file:  ParlaMint-RS_2005-09-13-0.conllu
# Done with file:  ParlaMint-RS_2005-09-14-0.conllu
# Done with file:  ParlaMint-RS_2005-09-15-0.conllu
# Done with file:  ParlaMint-RS_2005-09-16-0.conllu
# Done with file:  ParlaMint-RS_2005-09-19-0.conllu
# Done with file:  ParlaMint-RS_2005-09-20-0.conllu
# Done with file:  ParlaMint-RS_2005-09-21-0.conllu
# Done with file:  ParlaMint-RS_2005-09-22-0.conllu
# Done with file:  ParlaMint-RS_2005-09-26-0.conllu
# Done with file:  ParlaMint-RS_2005-09-27-0.conllu
# Done with file:  ParlaMint-RS_2005-09-28-0.conllu
# Done with file:  ParlaMint-RS_2005-09-29-0.conllu
# Done with file:  ParlaMint-RS_2005-10-11-0.conllu
# Done with file:  ParlaMint-RS_2005-10-12-0.conllu
# Done with file:  ParlaMint-RS_2005-10-13-0.conllu
# Done with file:  ParlaMint-RS_2005-10-18-0.conllu
# Done with file:  ParlaMint-RS_2005-10-20-0.conllu
# Done with file:  ParlaMint-RS_2005-10-24-0.conllu
# Done with file:  ParlaMint-RS_2005-10-25-0.conllu
# Done with file:  ParlaMint-RS_2005-10-26-0.conllu
# Done with file:  ParlaMint-RS_2005-10-31-0.conllu
# Done with file:  ParlaMint-RS_2005-11-01-0.conllu
# Done with file:  ParlaMint-RS_2005-11-02-0.conllu
# Done with file:  ParlaMint-RS_2005-11-03-0.conllu
# Done with file:  ParlaMint-RS_2005-11-08-0.conllu
# Done with file:  ParlaMint-RS_2005-11-09-0.conllu
# Done with file:  ParlaMint-RS_2005-11-10-0.conllu
# Done with file:  ParlaMint-RS_2005-11-14-0.conllu
# Done with file:  ParlaMint-RS_2005-11-15-0.conllu
# Done with file:  ParlaMint-RS_2005-11-16-0.conllu
# Done with file:  ParlaMint-RS_2005-11-17-0.conllu
# Done with file:  ParlaMint-RS_2005-11-18-0.conllu
# Done with file:  ParlaMint-RS_2005-11-21-0.conllu
# Done with file:  ParlaMint-RS_2005-11-22-0.conllu
# Done with file:  ParlaMint-RS_2005-11-23-0.conllu
# Done with file:  ParlaMint-RS_2005-11-24-0.conllu
# Done with file:  ParlaMint-RS_2005-11-25-0.conllu
# Done with file:  ParlaMint-RS_2005-11-26-0.conllu
# Done with file:  ParlaMint-RS_2005-11-27-0.conllu
# Done with file:  ParlaMint-RS_2005-11-28-0.conllu
# Done with file:  ParlaMint-RS_2005-11-29-0.conllu
# Done with file:  ParlaMint-RS_2005-11-30-0.conllu
# Done with file:  ParlaMint-RS_2005-12-01-0.conllu
# Done with file:  ParlaMint-RS_2005-12-08-0.conllu
# Done with file:  ParlaMint-RS_2005-12-12-0.conllu
# Done with file:  ParlaMint-RS_2005-12-13-0.conllu
# Done with file:  ParlaMint-RS_2005-12-14-0.conllu
# Done with file:  ParlaMint-RS_2005-12-15-0.conllu
# Done with file:  ParlaMint-RS_2005-12-20-0.conllu
# Done with file:  ParlaMint-RS_2005-12-21-0.conllu
# Done with file:  ParlaMint-RS_2005-12-22-0.conllu
# Done with file:  ParlaMint-RS_2006-02-27-0.conllu
# Done with file:  ParlaMint-RS_2006-03-27-0.conllu
# Done with file:  ParlaMint-RS_2006-03-28-0.conllu
# Done with file:  ParlaMint-RS_2006-03-29-0.conllu
# Done with file:  ParlaMint-RS_2006-04-03-0.conllu
# Done with file:  ParlaMint-RS_2006-04-04-0.conllu
# Done with file:  ParlaMint-RS_2006-04-05-0.conllu
# Done with file:  ParlaMint-RS_2006-04-06-0.conllu
# Done with file:  ParlaMint-RS_2006-04-10-0.conllu
# Done with file:  ParlaMint-RS_2006-04-11-0.conllu
# Done with file:  ParlaMint-RS_2006-04-12-0.conllu
# Done with file:  ParlaMint-RS_2006-04-13-0.conllu
# Done with file:  ParlaMint-RS_2006-04-17-0.conllu
# Done with file:  ParlaMint-RS_2006-04-18-0.conllu
# Done with file:  ParlaMint-RS_2006-04-19-0.conllu
# Done with file:  ParlaMint-RS_2006-04-20-0.conllu
# Done with file:  ParlaMint-RS_2006-05-08-0.conllu
# Done with file:  ParlaMint-RS_2006-05-09-0.conllu
# Done with file:  ParlaMint-RS_2006-05-10-0.conllu
# Done with file:  ParlaMint-RS_2006-05-11-0.conllu
# Done with file:  ParlaMint-RS_2006-05-12-0.conllu
# Done with file:  ParlaMint-RS_2006-05-16-0.conllu
# Done with file:  ParlaMint-RS_2006-05-17-0.conllu
# Done with file:  ParlaMint-RS_2006-05-18-0.conllu
# Done with file:  ParlaMint-RS_2006-05-19-0.conllu
# Done with file:  ParlaMint-RS_2006-05-22-0.conllu
# Done with file:  ParlaMint-RS_2006-05-23-0.conllu
# Done with file:  ParlaMint-RS_2006-05-24-0.conllu
# Done with file:  ParlaMint-RS_2006-05-25-0.conllu
# Done with file:  ParlaMint-RS_2006-06-05-0.conllu
# Done with file:  ParlaMint-RS_2006-06-06-0.conllu
# Done with file:  ParlaMint-RS_2006-06-08-0.conllu
# Done with file:  ParlaMint-RS_2006-06-12-0.conllu
# Done with file:  ParlaMint-RS_2006-06-13-0.conllu
# Done with file:  ParlaMint-RS_2006-06-14-0.conllu
# Done with file:  ParlaMint-RS_2006-06-15-0.conllu
# Done with file:  ParlaMint-RS_2006-06-19-0.conllu
# Done with file:  ParlaMint-RS_2006-06-20-0.conllu
# Done with file:  ParlaMint-RS_2006-06-21-0.conllu
# Done with file:  ParlaMint-RS_2006-06-22-0.conllu
# Done with file:  ParlaMint-RS_2006-06-27-0.conllu
# Done with file:  ParlaMint-RS_2006-06-29-0.conllu
# Done with file:  ParlaMint-RS_2006-07-04-0.conllu
# Done with file:  ParlaMint-RS_2006-07-05-0.conllu
# Done with file:  ParlaMint-RS_2006-07-06-0.conllu
# Done with file:  ParlaMint-RS_2006-07-14-0.conllu
# Done with file:  ParlaMint-RS_2006-07-18-0.conllu
# Done with file:  ParlaMint-RS_2006-07-19-0.conllu
# Done with file:  ParlaMint-RS_2006-09-12-0.conllu
# Done with file:  ParlaMint-RS_2006-09-25-0.conllu
# Done with file:  ParlaMint-RS_2006-09-27-0.conllu
# Done with file:  ParlaMint-RS_2006-09-28-0.conllu
# Done with file:  ParlaMint-RS_2006-09-30-0.conllu
# Done with file:  ParlaMint-RS_2006-10-08-0.conllu
# Done with file:  ParlaMint-RS_2006-10-09-0.conllu
# Done with file:  ParlaMint-RS_2006-11-08-0.conllu
# Done with file:  ParlaMint-RS_2006-11-09-0.conllu
# Done with file:  ParlaMint-RS_2007-02-14-0.conllu
# Done with file:  ParlaMint-RS_2007-02-14-1.conllu
# Done with file:  ParlaMint-RS_2007-05-07-0.conllu
# Done with file:  ParlaMint-RS_2007-05-08-0.conllu
# Done with file:  ParlaMint-RS_2007-05-09-0.conllu
# Done with file:  ParlaMint-RS_2007-05-12-0.conllu
# Done with file:  ParlaMint-RS_2007-05-13-0.conllu
# Done with file:  ParlaMint-RS_2007-05-14-0.conllu
# Done with file:  ParlaMint-RS_2007-05-15-0.conllu
# Done with file:  ParlaMint-RS_2007-05-22-0.conllu
# Done with file:  ParlaMint-RS_2007-05-23-0.conllu
# Done with file:  ParlaMint-RS_2007-05-25-0.conllu
# Done with file:  ParlaMint-RS_2007-05-28-0.conllu
# Done with file:  ParlaMint-RS_2007-05-29-0.conllu
# Done with file:  ParlaMint-RS_2007-05-30-0.conllu
# Done with file:  ParlaMint-RS_2007-06-08-0.conllu
# Done with file:  ParlaMint-RS_2007-06-12-0.conllu
# Done with file:  ParlaMint-RS_2007-06-13-0.conllu
# Done with file:  ParlaMint-RS_2007-06-18-0.conllu
# Done with file:  ParlaMint-RS_2007-06-19-0.conllu
# Done with file:  ParlaMint-RS_2007-06-20-0.conllu
# Done with file:  ParlaMint-RS_2007-06-21-0.conllu
# Done with file:  ParlaMint-RS_2007-06-22-0.conllu
# Done with file:  ParlaMint-RS_2007-06-26-0.conllu
# Done with file:  ParlaMint-RS_2007-06-27-0.conllu
# Done with file:  ParlaMint-RS_2007-06-29-0.conllu
# Done with file:  ParlaMint-RS_2007-07-03-0.conllu
# Done with file:  ParlaMint-RS_2007-07-05-0.conllu
# Done with file:  ParlaMint-RS_2007-07-13-0.conllu
# Done with file:  ParlaMint-RS_2007-07-16-0.conllu
# Done with file:  ParlaMint-RS_2007-07-17-0.conllu
# Done with file:  ParlaMint-RS_2007-07-18-0.conllu
# Done with file:  ParlaMint-RS_2007-07-23-0.conllu
# Done with file:  ParlaMint-RS_2007-07-24-0.conllu
# Done with file:  ParlaMint-RS_2007-09-11-0.conllu
# Done with file:  ParlaMint-RS_2007-09-12-0.conllu
# Done with file:  ParlaMint-RS_2007-09-13-0.conllu
# Done with file:  ParlaMint-RS_2007-09-14-0.conllu
# Done with file:  ParlaMint-RS_2007-09-17-0.conllu
# Done with file:  ParlaMint-RS_2007-09-18-0.conllu
# Done with file:  ParlaMint-RS_2007-09-19-0.conllu
# Done with file:  ParlaMint-RS_2007-09-20-0.conllu
# Done with file:  ParlaMint-RS_2007-09-24-0.conllu
# Done with file:  ParlaMint-RS_2007-09-25-0.conllu
# Done with file:  ParlaMint-RS_2007-09-26-0.conllu
# Done with file:  ParlaMint-RS_2007-10-01-0.conllu
# Done with file:  ParlaMint-RS_2007-10-02-0.conllu
# Done with file:  ParlaMint-RS_2007-10-03-0.conllu
# Done with file:  ParlaMint-RS_2007-10-04-0.conllu
# Done with file:  ParlaMint-RS_2007-10-08-0.conllu
# Done with file:  ParlaMint-RS_2007-10-09-0.conllu
# Done with file:  ParlaMint-RS_2007-10-10-0.conllu
# Done with file:  ParlaMint-RS_2007-10-11-0.conllu
# Done with file:  ParlaMint-RS_2007-10-15-0.conllu
# Done with file:  ParlaMint-RS_2007-10-16-0.conllu
# Done with file:  ParlaMint-RS_2007-10-17-0.conllu
# Done with file:  ParlaMint-RS_2007-10-18-0.conllu
# Done with file:  ParlaMint-RS_2007-10-23-0.conllu
# Done with file:  ParlaMint-RS_2007-10-24-0.conllu
# Done with file:  ParlaMint-RS_2007-10-25-0.conllu
# Done with file:  ParlaMint-RS_2007-10-26-0.conllu
# Done with file:  ParlaMint-RS_2007-10-29-0.conllu
# Done with file:  ParlaMint-RS_2007-10-30-0.conllu
# Done with file:  ParlaMint-RS_2007-10-31-0.conllu
# Done with file:  ParlaMint-RS_2007-11-05-0.conllu
# Done with file:  ParlaMint-RS_2007-11-06-0.conllu
# Done with file:  ParlaMint-RS_2007-11-07-0.conllu
# Done with file:  ParlaMint-RS_2007-11-08-0.conllu
# Done with file:  ParlaMint-RS_2007-11-09-0.conllu
# Done with file:  ParlaMint-RS_2007-11-12-0.conllu
# Done with file:  ParlaMint-RS_2007-11-13-0.conllu
# Done with file:  ParlaMint-RS_2007-11-14-0.conllu
# Done with file:  ParlaMint-RS_2007-11-15-0.conllu
# Done with file:  ParlaMint-RS_2007-11-16-0.conllu
# Done with file:  ParlaMint-RS_2007-11-19-0.conllu
# Done with file:  ParlaMint-RS_2007-11-20-0.conllu
# Done with file:  ParlaMint-RS_2007-11-21-0.conllu
# Done with file:  ParlaMint-RS_2007-11-22-0.conllu
# Done with file:  ParlaMint-RS_2007-11-23-0.conllu
# Done with file:  ParlaMint-RS_2007-11-24-0.conllu
# Done with file:  ParlaMint-RS_2007-11-26-0.conllu
# Done with file:  ParlaMint-RS_2007-11-28-0.conllu
# Done with file:  ParlaMint-RS_2007-11-29-0.conllu
# Done with file:  ParlaMint-RS_2007-11-30-0.conllu
# Done with file:  ParlaMint-RS_2007-12-03-0.conllu
# Done with file:  ParlaMint-RS_2007-12-04-0.conllu
# Done with file:  ParlaMint-RS_2007-12-05-0.conllu
# Done with file:  ParlaMint-RS_2007-12-06-0.conllu
# Done with file:  ParlaMint-RS_2007-12-07-0.conllu
# Done with file:  ParlaMint-RS_2007-12-10-0.conllu
# Done with file:  ParlaMint-RS_2007-12-11-0.conllu
# Done with file:  ParlaMint-RS_2007-12-12-0.conllu
# Done with file:  ParlaMint-RS_2007-12-13-0.conllu
# Done with file:  ParlaMint-RS_2007-12-14-0.conllu
# Done with file:  ParlaMint-RS_2007-12-17-0.conllu
# Done with file:  ParlaMint-RS_2007-12-18-0.conllu
# Done with file:  ParlaMint-RS_2007-12-19-0.conllu
# Done with file:  ParlaMint-RS_2007-12-20-0.conllu
# Done with file:  ParlaMint-RS_2007-12-21-0.conllu
# Done with file:  ParlaMint-RS_2007-12-24-0.conllu
# Done with file:  ParlaMint-RS_2007-12-25-0.conllu
# Done with file:  ParlaMint-RS_2007-12-26-0.conllu
# Done with file:  ParlaMint-RS_2007-12-27-0.conllu
# Done with file:  ParlaMint-RS_2007-12-29-0.conllu
# Done with file:  ParlaMint-RS_2008-02-15-0.conllu
# Done with file:  ParlaMint-RS_2008-02-18-0.conllu
# Done with file:  ParlaMint-RS_2008-02-29-0.conllu
# Done with file:  ParlaMint-RS_2008-03-05-0.conllu
# Done with file:  ParlaMint-RS_2008-06-11-0.conllu
# Done with file:  ParlaMint-RS_2008-06-24-0.conllu
# Done with file:  ParlaMint-RS_2008-06-25-0.conllu
# Done with file:  ParlaMint-RS_2008-06-26-0.conllu
# Done with file:  ParlaMint-RS_2008-06-27-0.conllu
# Done with file:  ParlaMint-RS_2008-06-30-0.conllu
# Done with file:  ParlaMint-RS_2008-07-01-0.conllu
# Done with file:  ParlaMint-RS_2008-07-02-0.conllu
# Done with file:  ParlaMint-RS_2008-07-03-0.conllu
# Done with file:  ParlaMint-RS_2008-07-04-0.conllu
# Done with file:  ParlaMint-RS_2008-07-07-0.conllu
# Done with file:  ParlaMint-RS_2008-07-16-0.conllu
# Done with file:  ParlaMint-RS_2008-07-17-0.conllu
# Done with file:  ParlaMint-RS_2008-07-18-0.conllu
# Done with file:  ParlaMint-RS_2008-07-21-0.conllu
# Done with file:  ParlaMint-RS_2008-09-02-0.conllu
# Done with file:  ParlaMint-RS_2008-09-03-0.conllu
# Done with file:  ParlaMint-RS_2008-09-04-0.conllu
# Done with file:  ParlaMint-RS_2008-09-05-0.conllu
# Done with file:  ParlaMint-RS_2008-09-08-0.conllu
# Done with file:  ParlaMint-RS_2008-09-15-0.conllu
# Done with file:  ParlaMint-RS_2008-09-25-0.conllu
# Done with file:  ParlaMint-RS_2008-09-26-0.conllu
# Done with file:  ParlaMint-RS_2008-09-29-0.conllu
# Done with file:  ParlaMint-RS_2008-09-30-0.conllu
# Done with file:  ParlaMint-RS_2008-10-07-0.conllu
# Done with file:  ParlaMint-RS_2008-10-08-0.conllu
# Done with file:  ParlaMint-RS_2008-10-09-0.conllu
# Done with file:  ParlaMint-RS_2008-10-10-0.conllu
# Done with file:  ParlaMint-RS_2008-10-14-0.conllu
# Done with file:  ParlaMint-RS_2008-10-15-0.conllu
# Done with file:  ParlaMint-RS_2008-10-16-0.conllu
# Done with file:  ParlaMint-RS_2008-10-17-0.conllu
# Done with file:  ParlaMint-RS_2008-10-18-0.conllu
# Done with file:  ParlaMint-RS_2008-10-20-0.conllu
# Done with file:  ParlaMint-RS_2008-10-21-0.conllu
# Done with file:  ParlaMint-RS_2008-10-22-0.conllu
# Done with file:  ParlaMint-RS_2008-10-23-0.conllu
# Done with file:  ParlaMint-RS_2008-10-24-0.conllu
# Done with file:  ParlaMint-RS_2008-10-28-0.conllu
# Done with file:  ParlaMint-RS_2008-10-29-0.conllu
# Done with file:  ParlaMint-RS_2008-10-30-0.conllu
# Done with file:  ParlaMint-RS_2008-10-31-0.conllu
# Done with file:  ParlaMint-RS_2008-11-03-0.conllu
# Done with file:  ParlaMint-RS_2008-11-04-0.conllu
# Done with file:  ParlaMint-RS_2008-11-05-0.conllu
# Done with file:  ParlaMint-RS_2008-11-11-0.conllu
# Done with file:  ParlaMint-RS_2008-11-12-0.conllu
# Done with file:  ParlaMint-RS_2008-11-13-0.conllu
# Done with file:  ParlaMint-RS_2008-11-14-0.conllu
# Done with file:  ParlaMint-RS_2008-11-18-0.conllu
# Done with file:  ParlaMint-RS_2008-11-19-0.conllu
# Done with file:  ParlaMint-RS_2008-11-20-0.conllu
# Done with file:  ParlaMint-RS_2008-11-24-0.conllu
# Done with file:  ParlaMint-RS_2008-11-25-0.conllu
# Done with file:  ParlaMint-RS_2008-11-26-0.conllu
# Done with file:  ParlaMint-RS_2008-11-27-0.conllu
# Done with file:  ParlaMint-RS_2008-11-28-0.conllu
# Done with file:  ParlaMint-RS_2008-12-01-0.conllu
# Done with file:  ParlaMint-RS_2008-12-02-0.conllu
# Done with file:  ParlaMint-RS_2008-12-03-0.conllu
# Done with file:  ParlaMint-RS_2008-12-04-0.conllu
# Done with file:  ParlaMint-RS_2008-12-05-0.conllu
# Done with file:  ParlaMint-RS_2008-12-08-0.conllu
# Done with file:  ParlaMint-RS_2008-12-09-0.conllu
# Done with file:  ParlaMint-RS_2008-12-10-0.conllu
# Done with file:  ParlaMint-RS_2008-12-11-0.conllu
# Done with file:  ParlaMint-RS_2008-12-12-0.conllu
# Done with file:  ParlaMint-RS_2008-12-13-0.conllu
# Done with file:  ParlaMint-RS_2008-12-15-0.conllu
# Done with file:  ParlaMint-RS_2008-12-16-0.conllu
# Done with file:  ParlaMint-RS_2008-12-17-0.conllu
# Done with file:  ParlaMint-RS_2008-12-18-0.conllu
# Done with file:  ParlaMint-RS_2008-12-22-0.conllu
# Done with file:  ParlaMint-RS_2008-12-23-0.conllu
# Done with file:  ParlaMint-RS_2008-12-24-0.conllu
# Done with file:  ParlaMint-RS_2008-12-26-0.conllu
# Done with file:  ParlaMint-RS_2008-12-27-0.conllu
# Done with file:  ParlaMint-RS_2008-12-28-0.conllu
# Done with file:  ParlaMint-RS_2008-12-29-0.conllu
# Done with file:  ParlaMint-RS_2008-12-30-0.conllu
# Done with file:  ParlaMint-RS_2009-01-12-0.conllu
# Done with file:  ParlaMint-RS_2009-01-14-0.conllu
# Done with file:  ParlaMint-RS_2009-01-15-0.conllu
# Done with file:  ParlaMint-RS_2009-01-16-0.conllu
# Done with file:  ParlaMint-RS_2009-01-19-0.conllu
# Done with file:  ParlaMint-RS_2009-01-21-0.conllu
# Done with file:  ParlaMint-RS_2009-01-22-0.conllu
# Done with file:  ParlaMint-RS_2009-01-23-0.conllu
# Done with file:  ParlaMint-RS_2009-01-26-0.conllu
# Done with file:  ParlaMint-RS_2009-01-27-0.conllu
# Done with file:  ParlaMint-RS_2009-01-28-0.conllu
# Done with file:  ParlaMint-RS_2009-01-29-0.conllu
# Done with file:  ParlaMint-RS_2009-02-02-0.conllu
# Done with file:  ParlaMint-RS_2009-02-10-0.conllu
# Done with file:  ParlaMint-RS_2009-02-11-0.conllu
# Done with file:  ParlaMint-RS_2009-02-12-0.conllu
# Done with file:  ParlaMint-RS_2009-02-13-0.conllu
# Done with file:  ParlaMint-RS_2009-02-17-0.conllu
# Done with file:  ParlaMint-RS_2009-02-26-0.conllu
# Done with file:  ParlaMint-RS_2009-03-05-0.conllu
# Done with file:  ParlaMint-RS_2009-03-06-0.conllu
# Done with file:  ParlaMint-RS_2009-03-10-0.conllu
# Done with file:  ParlaMint-RS_2009-03-11-0.conllu
# Done with file:  ParlaMint-RS_2009-03-12-0.conllu
# Done with file:  ParlaMint-RS_2009-03-13-0.conllu
# Done with file:  ParlaMint-RS_2009-03-18-0.conllu
# Done with file:  ParlaMint-RS_2009-03-19-0.conllu
# Done with file:  ParlaMint-RS_2009-03-23-0.conllu
# Done with file:  ParlaMint-RS_2009-03-25-0.conllu
# Done with file:  ParlaMint-RS_2009-03-26-0.conllu
# Done with file:  ParlaMint-RS_2009-03-27-0.conllu
# Done with file:  ParlaMint-RS_2009-03-30-0.conllu
# Done with file:  ParlaMint-RS_2009-03-31-0.conllu
# Done with file:  ParlaMint-RS_2009-04-01-0.conllu
# Done with file:  ParlaMint-RS_2009-04-02-0.conllu
# Done with file:  ParlaMint-RS_2009-04-03-0.conllu
# Done with file:  ParlaMint-RS_2009-04-06-0.conllu
# Done with file:  ParlaMint-RS_2009-04-07-0.conllu
# Done with file:  ParlaMint-RS_2009-04-08-0.conllu
# Done with file:  ParlaMint-RS_2009-04-09-0.conllu
# Done with file:  ParlaMint-RS_2009-04-14-0.conllu
# Done with file:  ParlaMint-RS_2009-04-15-0.conllu
# Done with file:  ParlaMint-RS_2009-04-16-0.conllu
# Done with file:  ParlaMint-RS_2009-04-21-0.conllu
# Done with file:  ParlaMint-RS_2009-04-22-0.conllu
# Done with file:  ParlaMint-RS_2009-04-23-0.conllu
# Done with file:  ParlaMint-RS_2009-04-24-0.conllu
# Done with file:  ParlaMint-RS_2009-04-27-0.conllu
# Done with file:  ParlaMint-RS_2009-04-28-0.conllu
# Done with file:  ParlaMint-RS_2009-04-30-0.conllu
# Done with file:  ParlaMint-RS_2009-05-04-0.conllu
# Done with file:  ParlaMint-RS_2009-05-05-0.conllu
# Done with file:  ParlaMint-RS_2009-05-11-0.conllu
# Done with file:  ParlaMint-RS_2009-05-12-0.conllu
# Done with file:  ParlaMint-RS_2009-05-13-0.conllu
# Done with file:  ParlaMint-RS_2009-05-14-0.conllu
# Done with file:  ParlaMint-RS_2009-05-15-0.conllu
# Done with file:  ParlaMint-RS_2009-05-18-0.conllu
# Done with file:  ParlaMint-RS_2009-05-19-0.conllu
# Done with file:  ParlaMint-RS_2009-05-20-0.conllu
# Done with file:  ParlaMint-RS_2009-05-21-0.conllu
# Done with file:  ParlaMint-RS_2009-05-22-0.conllu
# Done with file:  ParlaMint-RS_2009-05-25-0.conllu
# Done with file:  ParlaMint-RS_2009-05-26-0.conllu
# Done with file:  ParlaMint-RS_2009-05-27-0.conllu
# Done with file:  ParlaMint-RS_2009-05-28-0.conllu
# Done with file:  ParlaMint-RS_2009-06-01-0.conllu
# Done with file:  ParlaMint-RS_2009-06-03-0.conllu
# Done with file:  ParlaMint-RS_2009-06-09-0.conllu
# Done with file:  ParlaMint-RS_2009-06-10-0.conllu
# Done with file:  ParlaMint-RS_2009-06-11-0.conllu
# Done with file:  ParlaMint-RS_2009-06-12-0.conllu
# Done with file:  ParlaMint-RS_2009-06-15-0.conllu
# Done with file:  ParlaMint-RS_2009-06-16-0.conllu
# Done with file:  ParlaMint-RS_2009-06-17-0.conllu
# Done with file:  ParlaMint-RS_2009-06-18-0.conllu
# Done with file:  ParlaMint-RS_2009-06-23-0.conllu
# Done with file:  ParlaMint-RS_2009-07-08-0.conllu
# Done with file:  ParlaMint-RS_2009-07-13-0.conllu
# Done with file:  ParlaMint-RS_2009-07-15-0.conllu
# Done with file:  ParlaMint-RS_2009-07-16-0.conllu
# Done with file:  ParlaMint-RS_2009-07-17-0.conllu
# Done with file:  ParlaMint-RS_2009-07-18-0.conllu
# Done with file:  ParlaMint-RS_2009-07-20-0.conllu
# Done with file:  ParlaMint-RS_2009-07-21-0.conllu
# Done with file:  ParlaMint-RS_2009-07-22-0.conllu
# Done with file:  ParlaMint-RS_2009-07-23-0.conllu
# Done with file:  ParlaMint-RS_2009-07-24-0.conllu
# Done with file:  ParlaMint-RS_2009-07-25-0.conllu
# Done with file:  ParlaMint-RS_2009-07-26-0.conllu
# Done with file:  ParlaMint-RS_2009-07-27-0.conllu
# Done with file:  ParlaMint-RS_2009-07-28-0.conllu
# Done with file:  ParlaMint-RS_2009-07-29-0.conllu
# Done with file:  ParlaMint-RS_2009-10-06-0.conllu
# Done with file:  ParlaMint-RS_2009-10-07-0.conllu
# Done with file:  ParlaMint-RS_2009-10-08-0.conllu
# Done with file:  ParlaMint-RS_2009-10-09-0.conllu
# Done with file:  ParlaMint-RS_2009-10-13-0.conllu
# Done with file:  ParlaMint-RS_2009-10-14-0.conllu
# Done with file:  ParlaMint-RS_2009-10-15-0.conllu
# Done with file:  ParlaMint-RS_2009-10-16-0.conllu
# Done with file:  ParlaMint-RS_2009-10-20-0.conllu
# Done with file:  ParlaMint-RS_2009-10-21-0.conllu
# Done with file:  ParlaMint-RS_2009-10-22-0.conllu
# Done with file:  ParlaMint-RS_2009-10-26-0.conllu
# Done with file:  ParlaMint-RS_2009-10-27-0.conllu
# Done with file:  ParlaMint-RS_2009-10-28-0.conllu
# Done with file:  ParlaMint-RS_2009-10-29-0.conllu
# Done with file:  ParlaMint-RS_2009-10-30-0.conllu
# Done with file:  ParlaMint-RS_2009-11-02-0.conllu
# Done with file:  ParlaMint-RS_2009-11-03-0.conllu
# Done with file:  ParlaMint-RS_2009-11-04-0.conllu
# Done with file:  ParlaMint-RS_2009-11-05-0.conllu
# Done with file:  ParlaMint-RS_2009-11-09-0.conllu
# Done with file:  ParlaMint-RS_2009-11-10-0.conllu
# Done with file:  ParlaMint-RS_2009-11-11-0.conllu
# Done with file:  ParlaMint-RS_2009-11-12-0.conllu
# Done with file:  ParlaMint-RS_2009-11-16-0.conllu
# Done with file:  ParlaMint-RS_2009-11-17-0.conllu
# Done with file:  ParlaMint-RS_2009-11-18-0.conllu
# Done with file:  ParlaMint-RS_2009-11-20-0.conllu
# Done with file:  ParlaMint-RS_2009-11-23-0.conllu
# Done with file:  ParlaMint-RS_2009-11-24-0.conllu
# Done with file:  ParlaMint-RS_2009-11-25-0.conllu
# Done with file:  ParlaMint-RS_2009-11-26-0.conllu
# Done with file:  ParlaMint-RS_2009-11-27-0.conllu
# Done with file:  ParlaMint-RS_2009-11-30-0.conllu
# Done with file:  ParlaMint-RS_2009-12-01-0.conllu
# Done with file:  ParlaMint-RS_2009-12-02-0.conllu
# Done with file:  ParlaMint-RS_2009-12-03-0.conllu
# Done with file:  ParlaMint-RS_2009-12-04-0.conllu
# Done with file:  ParlaMint-RS_2009-12-08-0.conllu
# Done with file:  ParlaMint-RS_2009-12-11-0.conllu
# Done with file:  ParlaMint-RS_2009-12-12-0.conllu
# Done with file:  ParlaMint-RS_2009-12-14-0.conllu
# Done with file:  ParlaMint-RS_2009-12-15-0.conllu
# Done with file:  ParlaMint-RS_2009-12-16-0.conllu
# Done with file:  ParlaMint-RS_2009-12-17-0.conllu
# Done with file:  ParlaMint-RS_2009-12-18-0.conllu
# Done with file:  ParlaMint-RS_2009-12-21-0.conllu
# Done with file:  ParlaMint-RS_2009-12-22-0.conllu
# Done with file:  ParlaMint-RS_2009-12-23-0.conllu
# Done with file:  ParlaMint-RS_2009-12-24-0.conllu
# Done with file:  ParlaMint-RS_2009-12-28-0.conllu
# Done with file:  ParlaMint-RS_2010-02-23-0.conllu
# Done with file:  ParlaMint-RS_2010-02-25-0.conllu
# Done with file:  ParlaMint-RS_2010-02-26-0.conllu
# Done with file:  ParlaMint-RS_2010-03-02-0.conllu
# Done with file:  ParlaMint-RS_2010-03-03-0.conllu
# Done with file:  ParlaMint-RS_2010-03-04-0.conllu
# Done with file:  ParlaMint-RS_2010-03-05-0.conllu
# Done with file:  ParlaMint-RS_2010-03-09-0.conllu
# Done with file:  ParlaMint-RS_2010-03-10-0.conllu
# Done with file:  ParlaMint-RS_2010-03-11-0.conllu
# Done with file:  ParlaMint-RS_2010-03-12-0.conllu
# Done with file:  ParlaMint-RS_2010-03-16-0.conllu
# Done with file:  ParlaMint-RS_2010-03-17-0.conllu
# Done with file:  ParlaMint-RS_2010-03-18-0.conllu
# Done with file:  ParlaMint-RS_2010-03-19-0.conllu
# Done with file:  ParlaMint-RS_2010-03-23-0.conllu
# Done with file:  ParlaMint-RS_2010-03-25-0.conllu
# Done with file:  ParlaMint-RS_2010-03-30-0.conllu
# Done with file:  ParlaMint-RS_2010-03-31-0.conllu
# Done with file:  ParlaMint-RS_2010-04-07-0.conllu
# Done with file:  ParlaMint-RS_2010-04-08-0.conllu
# Done with file:  ParlaMint-RS_2010-04-09-0.conllu
# Done with file:  ParlaMint-RS_2010-04-13-0.conllu
# Done with file:  ParlaMint-RS_2010-04-14-0.conllu
# Done with file:  ParlaMint-RS_2010-04-15-0.conllu
# Done with file:  ParlaMint-RS_2010-04-16-0.conllu
# Done with file:  ParlaMint-RS_2010-04-19-0.conllu
# Done with file:  ParlaMint-RS_2010-04-20-0.conllu
# Done with file:  ParlaMint-RS_2010-04-21-0.conllu
# Done with file:  ParlaMint-RS_2010-04-26-0.conllu
# Done with file:  ParlaMint-RS_2010-04-27-0.conllu
# Done with file:  ParlaMint-RS_2010-04-28-0.conllu
# Done with file:  ParlaMint-RS_2010-04-29-0.conllu
# Done with file:  ParlaMint-RS_2010-05-05-0.conllu
# Done with file:  ParlaMint-RS_2010-05-11-0.conllu
# Done with file:  ParlaMint-RS_2010-05-12-0.conllu
# Done with file:  ParlaMint-RS_2010-05-13-0.conllu
# Done with file:  ParlaMint-RS_2010-05-18-0.conllu
# Done with file:  ParlaMint-RS_2010-05-19-0.conllu
# Done with file:  ParlaMint-RS_2010-05-20-0.conllu
# Done with file:  ParlaMint-RS_2010-06-07-0.conllu
# Done with file:  ParlaMint-RS_2010-06-09-0.conllu
# Done with file:  ParlaMint-RS_2010-06-10-0.conllu
# Done with file:  ParlaMint-RS_2010-06-11-0.conllu
# Done with file:  ParlaMint-RS_2010-06-15-0.conllu
# Done with file:  ParlaMint-RS_2010-06-16-0.conllu
# Done with file:  ParlaMint-RS_2010-06-17-0.conllu
# Done with file:  ParlaMint-RS_2010-06-22-0.conllu
# Done with file:  ParlaMint-RS_2010-06-23-0.conllu
# Done with file:  ParlaMint-RS_2010-06-29-0.conllu
# Done with file:  ParlaMint-RS_2010-06-30-0.conllu
# Done with file:  ParlaMint-RS_2010-07-01-0.conllu
# Done with file:  ParlaMint-RS_2010-07-13-0.conllu
# Done with file:  ParlaMint-RS_2010-07-14-0.conllu
# Done with file:  ParlaMint-RS_2010-07-15-0.conllu
# Done with file:  ParlaMint-RS_2010-07-19-0.conllu
# Done with file:  ParlaMint-RS_2010-07-20-0.conllu
# Done with file:  ParlaMint-RS_2010-07-21-0.conllu
# Done with file:  ParlaMint-RS_2010-07-22-0.conllu
# Done with file:  ParlaMint-RS_2010-07-26-0.conllu
# Done with file:  ParlaMint-RS_2010-07-27-0.conllu
# Done with file:  ParlaMint-RS_2010-07-28-0.conllu
# Done with file:  ParlaMint-RS_2010-09-30-0.conllu
# ...
# Done with file:  ParlaMint-RS_2019-05-24-0.conllu
# Done with file:  ParlaMint-RS_2019-05-27-0.conllu
# Done with file:  ParlaMint-RS_2019-05-28-0.conllu
# Done with file:  ParlaMint-RS_2019-05-29-0.conllu
# Done with file:  ParlaMint-RS_2019-06-03-0.conllu
# Done with file:  ParlaMint-RS_2019-06-18-0.conllu
# Done with file:  ParlaMint-RS_2019-06-19-0.conllu
# Done with file:  ParlaMint-RS_2019-06-20-0.conllu
# Done with file:  ParlaMint-RS_2019-06-21-0.conllu
# Done with file:  ParlaMint-RS_2019-06-25-0.conllu
# Done with file:  ParlaMint-RS_2019-06-26-0.conllu
# Done with file:  ParlaMint-RS_2019-06-27-0.conllu
# Done with file:  ParlaMint-RS_2019-06-28-0.conllu
# Done with file:  ParlaMint-RS_2019-07-02-0.conllu
# Done with file:  ParlaMint-RS_2019-07-03-0.conllu
# Done with file:  ParlaMint-RS_2019-07-04-0.conllu
# Done with file:  ParlaMint-RS_2019-07-08-0.conllu
# Done with file:  ParlaMint-RS_2019-07-08-1.conllu
# Done with file:  ParlaMint-RS_2019-07-09-0.conllu
# Done with file:  ParlaMint-RS_2019-07-10-0.conllu
# Done with file:  ParlaMint-RS_2019-07-10-1.conllu
# Done with file:  ParlaMint-RS_2019-07-11-0.conllu
# Done with file:  ParlaMint-RS_2019-07-12-0.conllu
# Done with file:  ParlaMint-RS_2019-07-15-0.conllu
# Done with file:  ParlaMint-RS_2019-07-15-1.conllu
# Done with file:  ParlaMint-RS_2019-07-16-0.conllu
# Done with file:  ParlaMint-RS_2019-07-17-0.conllu
# Done with file:  ParlaMint-RS_2019-07-18-0.conllu
# Done with file:  ParlaMint-RS_2019-07-19-0.conllu
# Done with file:  ParlaMint-RS_2019-07-22-0.conllu
# Done with file:  ParlaMint-RS_2019-07-22-1.conllu
# Done with file:  ParlaMint-RS_2019-07-23-0.conllu
# Done with file:  ParlaMint-RS_2019-07-24-0.conllu
# Done with file:  ParlaMint-RS_2019-07-25-0.conllu
# Done with file:  ParlaMint-RS_2019-07-26-0.conllu
# Done with file:  ParlaMint-RS_2019-09-04-0.conllu
# Done with file:  ParlaMint-RS_2019-09-09-0.conllu
# Done with file:  ParlaMint-RS_2019-09-10-0.conllu
# Done with file:  ParlaMint-RS_2019-09-12-0.conllu
# Done with file:  ParlaMint-RS_2019-09-13-0.conllu
# Done with file:  ParlaMint-RS_2019-09-17-0.conllu
# Done with file:  ParlaMint-RS_2019-09-17-1.conllu
# Done with file:  ParlaMint-RS_2019-09-18-0.conllu
# Done with file:  ParlaMint-RS_2019-09-19-0.conllu
# Done with file:  ParlaMint-RS_2019-10-01-0.conllu
# Done with file:  ParlaMint-RS_2019-10-02-0.conllu
# Done with file:  ParlaMint-RS_2019-10-02-1.conllu
# Done with file:  ParlaMint-RS_2019-10-02-2.conllu
# Done with file:  ParlaMint-RS_2019-10-03-0.conllu
# Done with file:  ParlaMint-RS_2019-10-04-0.conllu
# Done with file:  ParlaMint-RS_2019-10-07-0.conllu
# Done with file:  ParlaMint-RS_2019-10-08-0.conllu
# Done with file:  ParlaMint-RS_2019-10-09-0.conllu
# Done with file:  ParlaMint-RS_2019-10-10-0.conllu
# Done with file:  ParlaMint-RS_2019-10-19-0.conllu
# Done with file:  ParlaMint-RS_2019-10-22-0.conllu
# Done with file:  ParlaMint-RS_2019-10-23-0.conllu
# Done with file:  ParlaMint-RS_2019-10-23-1.conllu
# Done with file:  ParlaMint-RS_2019-10-24-0.conllu
# Done with file:  ParlaMint-RS_2019-10-25-0.conllu
# Done with file:  ParlaMint-RS_2019-10-28-0.conllu
# Done with file:  ParlaMint-RS_2019-10-29-0.conllu
# Done with file:  ParlaMint-RS_2019-10-30-0.conllu
# Done with file:  ParlaMint-RS_2019-11-12-0.conllu
# Done with file:  ParlaMint-RS_2019-11-13-0.conllu
# Done with file:  ParlaMint-RS_2019-11-14-0.conllu
# Done with file:  ParlaMint-RS_2019-11-20-0.conllu
# Done with file:  ParlaMint-RS_2019-11-21-0.conllu
# Done with file:  ParlaMint-RS_2019-11-22-0.conllu
# Done with file:  ParlaMint-RS_2019-11-25-0.conllu
# Done with file:  ParlaMint-RS_2019-11-26-0.conllu
# Done with file:  ParlaMint-RS_2019-11-27-0.conllu
# Done with file:  ParlaMint-RS_2019-11-28-0.conllu
# Done with file:  ParlaMint-RS_2019-11-28-1.conllu
# Done with file:  ParlaMint-RS_2019-11-29-0.conllu
# Done with file:  ParlaMint-RS_2019-12-02-0.conllu
# Done with file:  ParlaMint-RS_2019-12-03-0.conllu
# Done with file:  ParlaMint-RS_2019-12-03-1.conllu
# Done with file:  ParlaMint-RS_2019-12-04-0.conllu
# Done with file:  ParlaMint-RS_2019-12-05-0.conllu
# Done with file:  ParlaMint-RS_2019-12-09-0.conllu
# Done with file:  ParlaMint-RS_2019-12-10-0.conllu
# Done with file:  ParlaMint-RS_2019-12-11-0.conllu
# Done with file:  ParlaMint-RS_2019-12-12-0.conllu
# Done with file:  ParlaMint-RS_2019-12-16-0.conllu
# Done with file:  ParlaMint-RS_2019-12-17-0.conllu
# Done with file:  ParlaMint-RS_2019-12-18-0.conllu
# Done with file:  ParlaMint-RS_2019-12-19-0.conllu
# Done with file:  ParlaMint-RS_2019-12-20-0.conllu
# Done with file:  ParlaMint-RS_2019-12-23-0.conllu
# Done with file:  ParlaMint-RS_2019-12-24-0.conllu
# Done with file:  ParlaMint-RS_2019-12-25-0.conllu
# Done with file:  ParlaMint-RS_2019-12-26-0.conllu
# Done with file:  ParlaMint-RS_2019-12-27-0.conllu
# Done with file:  ParlaMint-RS_2020-01-20-0.conllu
# Done with file:  ParlaMint-RS_2020-01-21-0.conllu
# Done with file:  ParlaMint-RS_2020-01-22-0.conllu
# Done with file:  ParlaMint-RS_2020-01-23-0.conllu
# Done with file:  ParlaMint-RS_2020-01-24-0.conllu
# Done with file:  ParlaMint-RS_2020-01-27-0.conllu
# Done with file:  ParlaMint-RS_2020-01-28-0.conllu
# Done with file:  ParlaMint-RS_2020-01-29-0.conllu
# Done with file:  ParlaMint-RS_2020-01-30-0.conllu
# Done with file:  ParlaMint-RS_2020-01-31-0.conllu
# Done with file:  ParlaMint-RS_2020-02-03-0.conllu
# Done with file:  ParlaMint-RS_2020-02-04-0.conllu
# Done with file:  ParlaMint-RS_2020-02-06-0.conllu
# Done with file:  ParlaMint-RS_2020-02-08-0.conllu
# Done with file:  ParlaMint-RS_2020-02-12-0.conllu
# Done with file:  ParlaMint-RS_2020-02-13-0.conllu
# Done with file:  ParlaMint-RS_2020-02-14-0.conllu
# Done with file:  ParlaMint-RS_2020-02-18-0.conllu
# Done with file:  ParlaMint-RS_2020-02-19-0.conllu
# Done with file:  ParlaMint-RS_2020-02-20-0.conllu
# Done with file:  ParlaMint-RS_2020-02-21-0.conllu
# Done with file:  ParlaMint-RS_2020-02-24-0.conllu
# Done with file:  ParlaMint-RS_2020-02-24-1.conllu
# Done with file:  ParlaMint-RS_2020-02-25-0.conllu
# Done with file:  ParlaMint-RS_2020-02-26-0.conllu
# Done with file:  ParlaMint-RS_2020-02-27-0.conllu
# Done with file:  ParlaMint-RS_2020-02-27-1.conllu
# Done with file:  ParlaMint-RS_2020-02-28-0.conllu
# Done with file:  ParlaMint-RS_2020-02-29-0.conllu
# Done with file:  ParlaMint-RS_2020-03-02-0.conllu
# Done with file:  ParlaMint-RS_2020-03-03-0.conllu
# Done with file:  ParlaMint-RS_2020-03-04-0.conllu
# Done with file:  ParlaMint-RS_2020-04-28-0.conllu
# Done with file:  ParlaMint-RS_2020-04-29-0.conllu
# Done with file:  ParlaMint-RS_2020-05-06-0.conllu
# Done with file:  ParlaMint-RS_2020-05-08-0.conllu
# Done with file:  ParlaMint-RS_2020-05-10-0.conllu
# Done with file:  ParlaMint-RS_2020-08-03-0.conllu
# Done with file:  ParlaMint-RS_2020-08-03-1.conllu
# Done with file:  ParlaMint-RS_2020-10-22-0.conllu
# Done with file:  ParlaMint-RS_2020-10-24-0.conllu
# Done with file:  ParlaMint-RS_2020-10-26-0.conllu
# Done with file:  ParlaMint-RS_2020-10-28-0.conllu
# Done with file:  ParlaMint-RS_2020-11-10-0.conllu
# Done with file:  ParlaMint-RS_2020-11-12-0.conllu
# Done with file:  ParlaMint-RS_2020-11-12-1.conllu
# Done with file:  ParlaMint-RS_2020-11-24-0.conllu
# Done with file:  ParlaMint-RS_2020-11-25-0.conllu
# Done with file:  ParlaMint-RS_2020-11-26-0.conllu
# Done with file:  ParlaMint-RS_2020-12-01-0.conllu
# Done with file:  ParlaMint-RS_2020-12-02-0.conllu
# Done with file:  ParlaMint-RS_2020-12-08-0.conllu
# Done with file:  ParlaMint-RS_2020-12-09-0.conllu
# Done with file:  ParlaMint-RS_2020-12-10-0.conllu
# Done with file:  ParlaMint-RS_2020-12-15-0.conllu
# Done with file:  ParlaMint-RS_2020-12-16-0.conllu
# Done with file:  ParlaMint-RS_2020-12-17-0.conllu
# Done with file:  ParlaMint-RS_2020-12-22-0.conllu
# Done with file:  ParlaMint-RS_2020-12-23-0.conllu
# Done with file:  ParlaMint-RS_2020-12-24-0.conllu
# Done with file:  ParlaMint-RS_2020-12-26-0.conllu
# Done with file:  ParlaMint-RS_2020-12-27-0.conllu
# Done with file:  ParlaMint-RS_2020-12-28-0.conllu
# Done with file:  ParlaMint-RS_2020-12-29-0.conllu
# Done with file:  ParlaMint-RS_2021-01-26-0.conllu
# Done with file:  ParlaMint-RS_2021-01-27-0.conllu
# Done with file:  ParlaMint-RS_2021-01-28-0.conllu
# Done with file:  ParlaMint-RS_2021-02-09-0.conllu
# Done with file:  ParlaMint-RS_2021-02-10-0.conllu
# Done with file:  ParlaMint-RS_2021-02-11-0.conllu
# Done with file:  ParlaMint-RS_2021-02-23-0.conllu
# Done with file:  ParlaMint-RS_2021-02-24-0.conllu
# Done with file:  ParlaMint-RS_2021-02-25-0.conllu
# Done with file:  ParlaMint-RS_2021-03-02-0.conllu
# Done with file:  ParlaMint-RS_2021-03-03-0.conllu
# Done with file:  ParlaMint-RS_2021-03-04-0.conllu
# Done with file:  ParlaMint-RS_2021-03-09-0.conllu
# Done with file:  ParlaMint-RS_2021-03-10-0.conllu
# Done with file:  ParlaMint-RS_2021-03-11-0.conllu
# Done with file:  ParlaMint-RS_2021-03-16-0.conllu
# Done with file:  ParlaMint-RS_2021-03-17-0.conllu
# Done with file:  ParlaMint-RS_2021-03-18-0.conllu
# Done with file:  ParlaMint-RS_2021-03-23-0.conllu
# Done with file:  ParlaMint-RS_2021-03-24-0.conllu
# Done with file:  ParlaMint-RS_2021-03-25-0.conllu
# Done with file:  ParlaMint-RS_2021-03-30-0.conllu
# Done with file:  ParlaMint-RS_2021-03-31-0.conllu
# Done with file:  ParlaMint-RS_2021-04-01-0.conllu
# Done with file:  ParlaMint-RS_2021-04-06-0.conllu
# Done with file:  ParlaMint-RS_2021-04-07-0.conllu
# Done with file:  ParlaMint-RS_2021-04-08-0.conllu
# Done with file:  ParlaMint-RS_2021-04-13-0.conllu
# Done with file:  ParlaMint-RS_2021-04-13-1.conllu
# Done with file:  ParlaMint-RS_2021-04-14-0.conllu
# Done with file:  ParlaMint-RS_2021-04-15-0.conllu
# Done with file:  ParlaMint-RS_2021-04-20-0.conllu
# Done with file:  ParlaMint-RS_2021-04-21-0.conllu
# Done with file:  ParlaMint-RS_2021-04-22-0.conllu
# Done with file:  ParlaMint-RS_2021-04-27-0.conllu
# Done with file:  ParlaMint-RS_2021-04-28-0.conllu
# Done with file:  ParlaMint-RS_2021-04-29-0.conllu
# Done with file:  ParlaMint-RS_2021-05-05-0.conllu
# Done with file:  ParlaMint-RS_2021-05-06-0.conllu
# Done with file:  ParlaMint-RS_2021-05-11-0.conllu
# Done with file:  ParlaMint-RS_2021-05-12-0.conllu
# Done with file:  ParlaMint-RS_2021-05-13-0.conllu
# Done with file:  ParlaMint-RS_2021-05-18-0.conllu
# Done with file:  ParlaMint-RS_2021-05-19-0.conllu
# Done with file:  ParlaMint-RS_2021-05-20-0.conllu
# Done with file:  ParlaMint-RS_2021-05-25-0.conllu
# Done with file:  ParlaMint-RS_2021-05-26-0.conllu
# Done with file:  ParlaMint-RS_2021-05-27-0.conllu
# Done with file:  ParlaMint-RS_2021-06-07-0.conllu
# Done with file:  ParlaMint-RS_2021-06-09-0.conllu
# Done with file:  ParlaMint-RS_2021-06-10-0.conllu
# Done with file:  ParlaMint-RS_2021-06-16-0.conllu
# Done with file:  ParlaMint-RS_2021-06-22-0.conllu
# Done with file:  ParlaMint-RS_2021-06-23-0.conllu
# Done with file:  ParlaMint-RS_2021-06-24-0.conllu
# Done with file:  ParlaMint-RS_2021-06-29-0.conllu
# Done with file:  ParlaMint-RS_2021-06-30-0.conllu
# Done with file:  ParlaMint-RS_2021-07-06-0.conllu
# Done with file:  ParlaMint-RS_2021-07-07-0.conllu
# Done with file:  ParlaMint-RS_2021-07-13-0.conllu
# Done with file:  ParlaMint-RS_2021-07-14-0.conllu
# Done with file:  ParlaMint-RS_2021-07-21-0.conllu
# Done with file:  ParlaMint-RS_2021-07-22-0.conllu
# Done with file:  ParlaMint-RS_2021-07-28-0.conllu
# Done with file:  ParlaMint-RS_2021-07-29-0.conllu
# Done with file:  ParlaMint-RS_2021-09-07-0.conllu
# Done with file:  ParlaMint-RS_2021-09-08-0.conllu
# Done with file:  ParlaMint-RS_2021-09-09-0.conllu
# Done with file:  ParlaMint-RS_2021-09-10-0.conllu
# Done with file:  ParlaMint-RS_2021-09-13-0.conllu
# Done with file:  ParlaMint-RS_2021-09-15-0.conllu
# Done with file:  ParlaMint-RS_2021-09-21-0.conllu
# Done with file:  ParlaMint-RS_2021-09-22-0.conllu
# Done with file:  ParlaMint-RS_2021-09-23-0.conllu
# Done with file:  ParlaMint-RS_2021-10-05-0.conllu
# Done with file:  ParlaMint-RS_2021-10-06-0.conllu
# Done with file:  ParlaMint-RS_2021-10-07-0.conllu
# Done with file:  ParlaMint-RS_2021-10-13-0.conllu
# Done with file:  ParlaMint-RS_2021-10-14-0.conllu
# Done with file:  ParlaMint-RS_2021-10-19-0.conllu
# Done with file:  ParlaMint-RS_2021-10-26-0.conllu
# Done with file:  ParlaMint-RS_2021-10-27-0.conllu
# Done with file:  ParlaMint-RS_2021-10-27-1.conllu
# Done with file:  ParlaMint-RS_2021-10-28-0.conllu
# Done with file:  ParlaMint-RS_2021-11-02-0.conllu
# Done with file:  ParlaMint-RS_2021-11-02-1.conllu
# Done with file:  ParlaMint-RS_2021-11-03-0.conllu
# Done with file:  ParlaMint-RS_2021-11-09-0.conllu
# Done with file:  ParlaMint-RS_2021-11-10-0.conllu
# Done with file:  ParlaMint-RS_2021-11-16-0.conllu
# Done with file:  ParlaMint-RS_2021-11-17-0.conllu
# Done with file:  ParlaMint-RS_2021-11-23-0.conllu
# Done with file:  ParlaMint-RS_2021-11-24-0.conllu
# Done with file:  ParlaMint-RS_2021-11-25-0.conllu
# Done with file:  ParlaMint-RS_2021-11-26-0.conllu
# Done with file:  ParlaMint-RS_2021-11-29-0.conllu
# Done with file:  ParlaMint-RS_2021-11-30-0.conllu
# Done with file:  ParlaMint-RS_2021-12-02-0.conllu
# Done with file:  ParlaMint-RS_2021-12-02-1.conllu
# Done with file:  ParlaMint-RS_2021-12-07-0.conllu
# Done with file:  ParlaMint-RS_2021-12-08-0.conllu
# Done with file:  ParlaMint-RS_2021-12-10-0.conllu
# Done with file:  ParlaMint-RS_2021-12-14-0.conllu
# Done with file:  ParlaMint-RS_2021-12-15-0.conllu
# Done with file:  ParlaMint-RS_2021-12-21-0.conllu
# Done with file:  ParlaMint-RS_2021-12-22-0.conllu
# Done with file:  ParlaMint-RS_2021-12-23-0.conllu
# Done with file:  ParlaMint-RS_2021-12-23-1.conllu
# Done with file:  ParlaMint-RS_2021-12-28-0.conllu
# Done with file:  ParlaMint-RS_2021-12-29-0.conllu
# Done with file:  ParlaMint-RS_2021-12-29-1.conllu
# Done with file:  ParlaMint-RS_2022-01-11-0.conllu
# Done with file:  ParlaMint-RS_2022-02-02-0.conllu
# Done with file:  ParlaMint-RS_2022-02-03-0.conllu
# Done with file:  ParlaMint-RS_2022-02-04-0.conllu
# Done with file:  ParlaMint-RS_2022-02-09-0.conllu
# Done with file:  ParlaMint-RS_2022-02-09-1.conllu
# Done with file:  ParlaMint-RS_2022-02-14-0.conllu
# Done with file:  ParlaMint-RS_2022-02-14-1.conllu
# Done with file:  ParlaMint-RS_2022-05-31-0.conllu
#                              ID              Title        Date           Body
# 0  ParlaMint-RS_1997-12-03-0.u1  Term 4, Meeting 1  1997-12-03  Unicameralism  \
# 1  ParlaMint-RS_1997-12-03-0.u2  Term 4, Meeting 1  1997-12-03  Unicameralism
# 2  ParlaMint-RS_1997-12-03-0.u3  Term 4, Meeting 1  1997-12-03  Unicameralism
# 3  ParlaMint-RS_1997-12-03-0.u4  Term 4, Meeting 1  1997-12-03  Unicameralism
# 4  ParlaMint-RS_1997-12-03-0.u5  Term 4, Meeting 1  1997-12-03  Unicameralism
#
#    Term  Session Meeting     Sitting  Agenda  Subcorpus Speaker_role
# 0     4      NaN       1  2000-10-09     NaN  Reference  Chairperson  \
# 1     4      NaN       1  2000-10-09     NaN  Reference      Regular
# 2     4      NaN       1  2000-10-09     NaN  Reference  Chairperson
# 3     4      NaN       1  2000-10-09     NaN  Reference      Regular
# 4     4      NaN       1  2000-10-09     NaN  Reference  Chairperson
#
#   Speaker_MP Speaker_Minister Speaker_party        Speaker_party_name
# 0         MP                -            LK                        LK  \
# 1         MP                -           SPO      Srpski pokret obnove
# 2         MP                -            LK                        LK
# 3         MP                -           SRS  Srpska radikalna stranka
# 4         MP                -            LK                        LK
#
#   Party_status       Speaker_name Speaker_gender Speaker_birth
# 0          NaN      Tomić, Dragan              M          1958  \
# 1   Opposition     Miković, Milan              M          1932
# 2          NaN      Tomić, Dragan              M          1958
# 3   Opposition  Nikolić, Tomislav              M          1952
# 4          NaN      Tomić, Dragan              M          1958
#
#                                               speech
# 0  Poštovane dame i gospodo, poštovani narodni po...
# 1  Gospodine predsedniče, dame i gospodo, naš juč...
# 2  Zahvaljujem. Ima reč narodni poslanik Tomislav...
# 3  Dame i gospodo, narodni poslanici, prvo vam če...
# 4  Ovo je bio dogovor. Mislim da nema nikakvog ra...

# %%
# conllu utilization of NERs
def mentions_network(directory, df):

    all_speakers = df.groupby('Speaker_name').first()

    df = df[df['Speaker_type'] == 'MP']
    df = df[df['Speaker_role'] != 'Chairperson']
    
    df.set_index('ID')

    graph = nx.DiGraph()
    for speaker, metadata in all_speakers.iterrows():
        speaker_speeches = len(df[df['Speaker_name'] == speaker])
        
        gender = metadata['Speaker_gender']

        party_name = metadata['Speaker_party_name']

        graph.add_node(speaker, party_name=party_name, gender=gender, speeches=speaker_speeches)

    # ---- READING THE CONLLU FILES AND ADDING NAMED ENTITY EDGES (MENTION NETWORKS)

    conllu_files_path = directory

    mps = None
    speaker_name = None
    speakers_mentioned_in_speech = set()
    for path, years, _ in os.walk(conllu_files_path):
        for year in years:
            conllu_files = path + year
            for file in os.listdir(conllu_files):
                if 'conllu' in file:
                    conllu_file = open(conllu_files + '/' + file, "r", encoding="utf-8")

                    process_speech = False  # flag if speech is in the preprocessed metadata
                    speech_id = None  # id to fetch the right metadata
                    for sentence in parse_incr(conllu_file):
                        if 'newdoc id' in sentence.metadata:

                            speech_id = sentence.metadata['newdoc id']
                            if speech_id in speech_metadata.index:
                                speaker_name = df.loc[speech_id]['Speaker_name']
                                mps = set(graph.nodes())
                                process_speech = True
                                speakers_mentioned_in_speech = set()
                            else:
                                process_speech = False  # speech should be skipped (either chair, or nonMP)

                        if process_speech:

                            # Finding the most probable person and adding an edge to the network
                            person = None
                            for token in sentence:
                                if token['misc'] == None or 'NER' not in token['misc']:
                                    continue
                                NER = token['misc']['NER']
                                if NER == 'B-PER':
                                    person = token['lemma']
                                elif NER == 'I-PER':
                                    person = person + ' ' + token['lemma']
                                else:
                                    if person != None:
                                        max_similarity = 0
                                        match = None
                                        possible_people = []
                                        for possible_person in all_speakers:
                                            similarity = fuzz.token_set_ratio(person, possible_person)
                                            if similarity == 100:
                                                possible_people.append(possible_person)

                                        if len(possible_people) == 1:
                                            match = possible_people[0]
                                            if match in mps and match not in speakers_mentioned_in_speech:
                                                if graph.has_edge(speaker_name, match):
                                                    graph[speaker_name][match]['weight'] += 1
                                                else:
                                                    graph.add_edge(speaker_name, match, weight=1)
                                                speakers_mentioned_in_speech.add(match)

                                        elif len(possible_people) > 1:
                                            speeches_before = list(
                                                speech_metadata_all.loc[:speech_id].tail(10)['Speaker_name'])
                                            speeches_after = list(
                                                speech_metadata_all.loc[speech_id:].head(10)['Speaker_name'])

                                            chronological_speakers = list(reversed(speeches_before)) + speeches_after

                                            for chronological_speaker in reversed(chronological_speakers):
                                                if chronological_speaker in possible_people:
                                                    match = chronological_speaker
                                                    if chronological_speaker in mps and chronological_speaker not in speakers_mentioned_in_speech:
                                                        if graph.has_edge(speaker_name, match):
                                                            graph[speaker_name][match]['weight'] += 1
                                                        else:
                                                            graph.add_edge(speaker_name, match, weight=1)
                                                        speakers_mentioned_in_speech.add(match)
                                                        break

                                        person = None
                        else:
                            continue
                print("Done with file: ", file)


    nx.readwrite.write_gexf(graph, 'graph.gexf')
